# %% [markdown]
# ![portada_visualizacion.jpg](attachment:portada_visualizacion.jpg)

# %%
import sys
sys.path.append("../")

# %%
import geopandas as gpd

# %%
from keplergl import KeplerGl

# %%
import pandas as pd

# %%
visualizacion = pd.read_csv('../data/visualizacion.csv', index_col = 0)

# %%
visualizacion['numero'] = 1

# %%
visualizacion
# Out:
#                                     name    latitud  longitud        tipo
# 0              Starbucks Room Mate Oscar  40.420752 -3.699315   Starbucks
# 1                  Starbucks Princesa 40  40.429069 -3.715079   Starbucks
# 2                  Starbucks Plaza Río 2  40.391304 -3.701123   Starbucks
# 3                      Starbucks Pozuelo  40.438168 -3.793838   Starbucks
# 4   Starbucks ECI Castellana (Starbucks)  40.447489 -3.693093   Starbucks
# ..                                   ...        ...       ...         ...
# 0                    Parada E.M.T. #1893  40.435149 -3.692567  Estaciones
# 1        Parada #60 (5, 14, 27, 45, 150)  40.433144 -3.688022  Estaciones
# 2                      Parada EMT del 27  40.432797 -3.688728  Estaciones
# 3                          Parada 27 EMT  40.432451 -3.687987  Estaciones
# 0         Clinica Veterinaria Castellana  40.436664 -3.692290         NaN
#
# [100 rows x 4 columns]

# %%
visualizacion.tipo.fillna('Veterinario', inplace=True)

# %%
visualizacion
# Out:
#                                     name    latitud  longitud         tipo
# 0              Starbucks Room Mate Oscar  40.420752 -3.699315    Starbucks
# 1                  Starbucks Princesa 40  40.429069 -3.715079    Starbucks
# 2                  Starbucks Plaza Río 2  40.391304 -3.701123    Starbucks
# 3                      Starbucks Pozuelo  40.438168 -3.793838    Starbucks
# 4   Starbucks ECI Castellana (Starbucks)  40.447489 -3.693093    Starbucks
# ..                                   ...        ...       ...          ...
# 0                    Parada E.M.T. #1893  40.435149 -3.692567   Estaciones
# 1        Parada #60 (5, 14, 27, 45, 150)  40.433144 -3.688022   Estaciones
# 2                      Parada EMT del 27  40.432797 -3.688728   Estaciones
# 3                          Parada 27 EMT  40.432451 -3.687987   Estaciones
# 0         Clinica Veterinaria Castellana  40.436664 -3.692290  Veterinario
#
# [100 rows x 4 columns]

# %%
map_1= KeplerGl(height=700, weight = 500, data={'name': visualizacion})
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
map_1
# Out:
# KeplerGl(data={'name':                                     name    latitud  longitud         tipo
# 0           …

# %%
config = map_1.config

# %%
with open('oficina_config.py', 'w') as f:
    f.write('config = {}'.format(map_1.config))

# %%
map_2= KeplerGl(height=700, data={'name': visualizacion}, config=config)
map_2
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'f78do0m', 'type': …

# %%
map_2.save_to_html(file_name = '../data/alrededores_oficina.html', read_only = True)
# Out:
# Map saved to ../data/alrededores_oficina.html!
